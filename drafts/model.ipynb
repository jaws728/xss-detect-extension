# %% [markdown]
# # First SVM XSS Demo

# %% [markdown]
# ## Defining Imports

# %%
# Regular Expressions
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split as tts
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
# from sklearn import metrics
import m2cgen as m2c 
# To ignore any warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Defining Constants

# %%
# Constants: XSS Features

URL = '(http://)|(https://)'
SYMBOLS = "[<>,\'\"/]&?\{\}"
WORDS = "(alert)|(script)|(%3c)|(%3e)|(%20)|(onerror)|(onload)|(eval)|(src=)|(prompt)|(onclick)|(document)|(window)|(iframe)|(location)|(img)|(div)|(break)|(.js)"

# %% [markdown]
# ## Defining Functions

# %%
# Extract Features

def get_features(url):
    is_url = 1 if re.search(URL, url, re.IGNORECASE) else 0
    xss_symbol_count = len(re.findall(SYMBOLS, url, re.IGNORECASE))
    xss_word_count = len(re.findall(WORDS, url, re.IGNORECASE))
    return [len(url), is_url, xss_symbol_count, xss_word_count]

def read_data(file, x, y, isXss):
    with open(file) as f:
        for line in f:
            x.append(get_features(line))
            if isXss: y.append(1)
            else: y.append(0)
    return x

# %%
# Evaluate model

def evaluate(name, y_test, y_pred):  
    """Calculate the main metrics supporting multi-target cases for a given model.  

    Args:
        name (str): The trained model's name
        y_test (series): Contains the ground truth values (aka y_true)
        y_pred (series): Contains the predicted values for the test set
        
    Returns:
        df_metrics (DataFrame): The predicted metrics in a DataFrame
        
    """
    dict_metrics = {
        'Accuracy Score': accuracy_score(y_test, y_pred),
        'Confusion Matrix': confusion_matrix(y_test, y_pred),
        'Precision Score': precision_score(y_test, y_pred),
        'Recall Score': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred)
    }
    #df_metrics = pd.DataFrame.from_dict
    df_metrics = pd.DataFrame.from_dict(dict_metrics, orient="index")
    df_metrics.columns = [name]
    return df_metrics

# %% [markdown]
# ## Prepare Data - read and split

# %%
# 1. Create x and y to store datas
x = []
y = []

# 2. Read datas and get features: scrapy + github
# xf = XSSFeatures()
read_data('../../datasets/gitee/xss-200000.txt', x, y, 1)
read_data('../../datasets/gitee/good-xss-200000.txt', x, y, 0)

# 3. Split datas into test and train: 0.6 of data using for train
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.4, random_state=0)

# %% [markdown]
# ## Classifiers and Tests

# %%
# %%time
# Support Vector Classification Linear kernel
svm = SVC(kernel='linear')
y_pred_svm = svm.fit(x_train, y_train).predict(x_test)

# Evaluate SVM model
evaluate("SVM Linear", y_test, y_pred_svm)
# Out:
# CPU times: user 1min 20s, sys: 1.36 s, total: 1min 22s
# Wall time: 1min 29s
#                                    SVM Linear
# Accuracy Score                       0.983087
# Confusion Matrix  [[53931, 234], [792, 5707]]
# Precision Score                      0.960613
# Recall Score                         0.878135
# F1 Score                             0.917524

# %%
# %%time
# Support Vector Classification RBF kernel
svm_rbf = SVC(kernel='rbf')
y_pred_svm_rbf = svm_rbf.fit(x_train, y_train).predict(x_test)

# Evaluate SVM model
evaluate("SVM RBF", y_test, y_pred_svm_rbf)
# Out:
# CPU times: user 59.3 s, sys: 796 ms, total: 1min
# Wall time: 1min 4s
#                                      SVM RBF
# Accuracy Score                      0.982642
# Confusion Matrix  [[54100, 65], [988, 5511]]
# Precision Score                     0.988343
# Recall Score                        0.847977
# F1 Score                            0.912795

# %%
# %%time
# Support Vector Classification RBF kernel
svm_poly = SVC(kernel='poly', degree=8)
y_pred_svm_poly = svm_poly.fit(x_train, y_train).predict(x_test)

# Evaluate SVM model
evaluate("SVM Poly", y_test, y_pred_svm_poly)
# Out:
# CPU times: user 1min 23s, sys: 1.44 s, total: 1min 24s
# Wall time: 1min 36s
#                                     SVM Poly
# Accuracy Score                      0.945767
# Confusion Matrix  [[54158, 7], [3283, 3216]]
# Precision Score                     0.997828
# Recall Score                        0.494845
# F1 Score                            0.661592

# %%
# %%time
# Linear Regression
reg = LinearRegression()
y_pred_reg = reg.fit(x_train, y_train).predict(x_test)

# Evaluate
evaluate("Linear Regression", y_test, y_pred_svm)
# Out:
# CPU times: user 416 ms, sys: 23.2 ms, total: 439 ms
# Wall time: 443 ms
#                             Linear Regression
# Accuracy Score                       0.983087
# Confusion Matrix  [[53931, 234], [792, 5707]]
# Precision Score                      0.960613
# Recall Score                         0.878135
# F1 Score                             0.917524

# %%
# %%time
# Naive Bayes Gaussian
gnb = GaussianNB()
y_pred_gnb = gnb.fit(x_train, y_train).predict(x_test)

# Evaluate
evaluate("NB Gaussian", y_test, y_pred_gnb)
# Out:
# CPU times: user 397 ms, sys: 13.7 ms, total: 411 ms
# Wall time: 573 ms
#                                    NB Gaussian
# Accuracy Score                        0.968136
# Confusion Matrix  [[53086, 1079], [854, 5645]]
# Precision Score                        0.83953
# Recall Score                          0.868595
# F1 Score                              0.853815

# %%
# 通过网格交叉验证的方式，找出效果最好的超参数
from sklearn.model_selection import GridSearchCV

knn = KNeighborsClassifier()

#定义需要尝试的超参数组合
grid = {"n_neighbors":range(1,11,1),"weights":['uniform','distance']}
'''
estimator:对哪个模型调整超参数
param_grid 需要验证的超参数组合。
scoring 模型评估标准
n_jobs %%bash发数量
cv 交叉验证折数
verbose 输出冗余信息，值越大，输出信息越多
'''
gs = GridSearchCV(estimator=knn,param_grid=grid,scoring="accuracy",n_jobs=-1,cv=5,verbose=10,return_train_score=True)
gs.fit(x_train, y_train)

# 最好的分值
print(gs.best_score_)

#最好的超参数组合
print(gs.best_params_)

#使用最好的超参数训练好的模型
print(gs.best_estimator_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 3/5; 1/20] START n_neighbors=1, weights=uniform.............................
# [CV 2/5; 1/20] START n_neighbors=1, weights=uniform.............................
# [CV 4/5; 1/20] START n_neighbors=1, weights=uniform.............................
# [CV 1/5; 1/20] START n_neighbors=1, weights=uniform.............................
# [CV 3/5; 1/20] END n_neighbors=1, weights=uniform;, score=(train=0.986, test=0.984) total time=   4.9s
# [CV 1/5; 1/20] END n_neighbors=1, weights=uniform;, score=(train=0.995, test=0.992) total time=   4.8s
# [CV 2/5; 1/20] END n_neighbors=1, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.8s
# [CV 5/5; 1/20] START n_neighbors=1, weights=uniform.............................
# [CV 4/5; 1/20] END n_neighbors=1, weights=uniform;, score=(train=0.986, test=0.986) total time=   4.8s
# [CV 1/5; 2/20] START n_neighbors=1, weights=distance............................
# [CV 2/5; 2/20] START n_neighbors=1, weights=distance............................
# [CV 3/5; 2/20] START n_neighbors=1, weights=distance............................
# [CV 1/5; 2/20] END n_neighbors=1, weights=distance;, score=(train=0.995, test=0.992) total time=   3.5s
# [CV 3/5; 2/20] END n_neighbors=1, weights=distance;, score=(train=0.986, test=0.984) total time=   3.4s
# [CV 4/5; 2/20] START n_neighbors=1, weights=distance............................
# [CV 2/5; 2/20] END n_neighbors=1, weights=distance;, score=(train=0.994, test=0.993) total time=   3.5s
# [CV 5/5; 2/20] START n_neighbors=1, weights=distance............................
# [CV 1/5; 3/20] START n_neighbors=2, weights=uniform.............................
# [CV 5/5; 1/20] END n_neighbors=1, weights=uniform;, score=(train=0.993, test=0.992) total time=   4.6s
# [CV 2/5; 3/20] START n_neighbors=2, weights=uniform.............................
# [CV 4/5; 2/20] END n_neighbors=1, weights=distance;, score=(train=0.986, test=0.986) total time=   3.3s
# [CV 3/5; 3/20] START n_neighbors=2, weights=uniform.............................
# [CV 5/5; 2/20] END n_neighbors=1, weights=distance;, score=(train=0.993, test=0.992) total time=   3.2s
# [CV 4/5; 3/20] START n_neighbors=2, weights=uniform.............................
# [CV 1/5; 3/20] END n_neighbors=2, weights=uniform;, score=(train=0.994, test=0.991) total time=   4.3s
# [CV 5/5; 3/20] START n_neighbors=2, weights=uniform.............................
# [CV 2/5; 3/20] END n_neighbors=2, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.7s
# [CV 1/5; 4/20] START n_neighbors=2, weights=distance............................
# [CV 3/5; 3/20] END n_neighbors=2, weights=uniform;, score=(train=0.994, test=0.992) total time=   4.5s
# [CV 2/5; 4/20] START n_neighbors=2, weights=distance............................
# [CV 4/5; 3/20] END n_neighbors=2, weights=uniform;, score=(train=0.993, test=0.994) total time=   4.6s
# [CV 3/5; 4/20] START n_neighbors=2, weights=distance............................
# [CV 1/5; 4/20] END n_neighbors=2, weights=distance;, score=(train=0.994, test=0.992) total time=   3.6s
# [CV 4/5; 4/20] START n_neighbors=2, weights=distance............................
# [CV 5/5; 3/20] END n_neighbors=2, weights=uniform;, score=(train=0.993, test=0.992) total time=   4.7s
# [CV 5/5; 4/20] START n_neighbors=2, weights=distance............................
# [CV 2/5; 4/20] END n_neighbors=2, weights=distance;, score=(train=0.994, test=0.993) total time=   3.4s
# [CV 1/5; 5/20] START n_neighbors=3, weights=uniform.............................
# [CV 3/5; 4/20] END n_neighbors=2, weights=distance;, score=(train=0.994, test=0.992) total time=   3.3s
# [CV 2/5; 5/20] START n_neighbors=3, weights=uniform.............................
# [CV 4/5; 4/20] END n_neighbors=2, weights=distance;, score=(train=0.993, test=0.994) total time=   3.6s
# [CV 3/5; 5/20] START n_neighbors=3, weights=uniform.............................
# [CV 5/5; 4/20] END n_neighbors=2, weights=distance;, score=(train=0.993, test=0.992) total time=   3.7s
# [CV 4/5; 5/20] START n_neighbors=3, weights=uniform.............................
# [CV 1/5; 5/20] END n_neighbors=3, weights=uniform;, score=(train=0.995, test=0.993) total time=   4.4s
# [CV 5/5; 5/20] START n_neighbors=3, weights=uniform.............................
# [CV 2/5; 5/20] END n_neighbors=3, weights=uniform;, score=(train=0.995, test=0.994) total time=   4.5s
# [CV 1/5; 6/20] START n_neighbors=3, weights=distance............................
# [CV 3/5; 5/20] END n_neighbors=3, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.4s
# [CV 2/5; 6/20] START n_neighbors=3, weights=distance............................
# [CV 4/5; 5/20] END n_neighbors=3, weights=uniform;, score=(train=0.994, test=0.995) total time=   4.5s
# [CV 3/5; 6/20] START n_neighbors=3, weights=distance............................
# [CV 1/5; 6/20] END n_neighbors=3, weights=distance;, score=(train=0.995, test=0.993) total time=   3.1s
# [CV 4/5; 6/20] START n_neighbors=3, weights=distance............................
# [CV 2/5; 6/20] END n_neighbors=3, weights=distance;, score=(train=0.995, test=0.994) total time=   3.4s
# [CV 5/5; 6/20] START n_neighbors=3, weights=distance............................
# [CV 5/5; 5/20] END n_neighbors=3, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.5s
# [CV 1/5; 7/20] START n_neighbors=4, weights=uniform.............................
# [CV 3/5; 6/20] END n_neighbors=3, weights=distance;, score=(train=0.995, test=0.993) total time=   3.3s
# [CV 2/5; 7/20] START n_neighbors=4, weights=uniform.............................
# [CV 4/5; 6/20] END n_neighbors=3, weights=distance;, score=(train=0.995, test=0.995) total time=   3.3s
# [CV 3/5; 7/20] START n_neighbors=4, weights=uniform.............................
# [CV 5/5; 6/20] END n_neighbors=3, weights=distance;, score=(train=0.994, test=0.994) total time=   3.4s
# [CV 4/5; 7/20] START n_neighbors=4, weights=uniform.............................
# [CV 1/5; 7/20] END n_neighbors=4, weights=uniform;, score=(train=0.995, test=0.993) total time=   4.6s
# [CV 5/5; 7/20] START n_neighbors=4, weights=uniform.............................
# [CV 2/5; 7/20] END n_neighbors=4, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.6s
# [CV 1/5; 8/20] START n_neighbors=4, weights=distance............................
# [CV 3/5; 7/20] END n_neighbors=4, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.5s
# [CV 2/5; 8/20] START n_neighbors=4, weights=distance............................
# [CV 4/5; 7/20] END n_neighbors=4, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.6s
# [CV 3/5; 8/20] START n_neighbors=4, weights=distance............................
# [CV 1/5; 8/20] END n_neighbors=4, weights=distance;, score=(train=0.995, test=0.993) total time=   3.5s
# [CV 4/5; 8/20] START n_neighbors=4, weights=distance............................
# [CV 5/5; 7/20] END n_neighbors=4, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.6s
# [CV 5/5; 8/20] START n_neighbors=4, weights=distance............................
# [CV 2/5; 8/20] END n_neighbors=4, weights=distance;, score=(train=0.995, test=0.994) total time=   3.4s
# [CV 1/5; 9/20] START n_neighbors=5, weights=uniform.............................
# [CV 3/5; 8/20] END n_neighbors=4, weights=distance;, score=(train=0.994, test=0.993) total time=   3.3s
# [CV 2/5; 9/20] START n_neighbors=5, weights=uniform.............................
# [CV 4/5; 8/20] END n_neighbors=4, weights=distance;, score=(train=0.994, test=0.994) total time=   3.3s
# [CV 3/5; 9/20] START n_neighbors=5, weights=uniform.............................
# [CV 5/5; 8/20] END n_neighbors=4, weights=distance;, score=(train=0.994, test=0.994) total time=   3.4s
# [CV 4/5; 9/20] START n_neighbors=5, weights=uniform.............................
# [CV 1/5; 9/20] END n_neighbors=5, weights=uniform;, score=(train=0.995, test=0.993) total time=   4.7s
# [CV 5/5; 9/20] START n_neighbors=5, weights=uniform.............................
# [CV 2/5; 9/20] END n_neighbors=5, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.4s
# [CV 1/5; 10/20] START n_neighbors=5, weights=distance...........................
# [CV 3/5; 9/20] END n_neighbors=5, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.4s
# [CV 2/5; 10/20] START n_neighbors=5, weights=distance...........................
# [CV 4/5; 9/20] END n_neighbors=5, weights=uniform;, score=(train=0.994, test=0.995) total time=   4.7s
# [CV 3/5; 10/20] START n_neighbors=5, weights=distance...........................
# [CV 1/5; 10/20] END n_neighbors=5, weights=distance;, score=(train=0.995, test=0.993) total time=   3.8s
# [CV 4/5; 10/20] START n_neighbors=5, weights=distance...........................
# [CV 5/5; 9/20] END n_neighbors=5, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.6s
# [CV 5/5; 10/20] START n_neighbors=5, weights=distance...........................
# [CV 2/5; 10/20] END n_neighbors=5, weights=distance;, score=(train=0.995, test=0.994) total time=   3.4s
# [CV 1/5; 11/20] START n_neighbors=6, weights=uniform............................
# [CV 3/5; 10/20] END n_neighbors=5, weights=distance;, score=(train=0.995, test=0.993) total time=   3.3s
# [CV 2/5; 11/20] START n_neighbors=6, weights=uniform............................
# [CV 4/5; 10/20] END n_neighbors=5, weights=distance;, score=(train=0.995, test=0.995) total time=   3.8s
# [CV 3/5; 11/20] START n_neighbors=6, weights=uniform............................
# [CV 5/5; 10/20] END n_neighbors=5, weights=distance;, score=(train=0.994, test=0.994) total time=   3.6s
# [CV 4/5; 11/20] START n_neighbors=6, weights=uniform............................
# [CV 1/5; 11/20] END n_neighbors=6, weights=uniform;, score=(train=0.995, test=0.993) total time=   4.8s
# [CV 5/5; 11/20] START n_neighbors=6, weights=uniform............................
# [CV 2/5; 11/20] END n_neighbors=6, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.6s
# [CV 1/5; 12/20] START n_neighbors=6, weights=distance...........................
# [CV 3/5; 11/20] END n_neighbors=6, weights=uniform;, score=(train=0.994, test=0.993) total time=   4.9s
# [CV 2/5; 12/20] START n_neighbors=6, weights=distance...........................
# [CV 4/5; 11/20] END n_neighbors=6, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.8s
# [CV 3/5; 12/20] START n_neighbors=6, weights=distance...........................
# [CV 1/5; 12/20] END n_neighbors=6, weights=distance;, score=(train=0.995, test=0.993) total time=   3.4s
# [CV 4/5; 12/20] START n_neighbors=6, weights=distance...........................
# [CV 5/5; 11/20] END n_neighbors=6, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.9s
# [CV 5/5; 12/20] START n_neighbors=6, weights=distance...........................
# [CV 2/5; 12/20] END n_neighbors=6, weights=distance;, score=(train=0.995, test=0.994) total time=   3.8s
# [CV 1/5; 13/20] START n_neighbors=7, weights=uniform............................
# [CV 3/5; 12/20] END n_neighbors=6, weights=distance;, score=(train=0.995, test=0.993) total time=   3.7s
# [CV 2/5; 13/20] START n_neighbors=7, weights=uniform............................
# [CV 4/5; 12/20] END n_neighbors=6, weights=distance;, score=(train=0.994, test=0.994) total time=   3.6s
# [CV 3/5; 13/20] START n_neighbors=7, weights=uniform............................
# [CV 5/5; 12/20] END n_neighbors=6, weights=distance;, score=(train=0.994, test=0.994) total time=   3.8s
# [CV 4/5; 13/20] START n_neighbors=7, weights=uniform............................
# [CV 1/5; 13/20] END n_neighbors=7, weights=uniform;, score=(train=0.995, test=0.993) total time=   5.2s
# [CV 5/5; 13/20] START n_neighbors=7, weights=uniform............................
# [CV 2/5; 13/20] END n_neighbors=7, weights=uniform;, score=(train=0.994, test=0.993) total time=   5.0s
# [CV 1/5; 14/20] START n_neighbors=7, weights=distance...........................
# [CV 3/5; 13/20] END n_neighbors=7, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.9s
# [CV 2/5; 14/20] START n_neighbors=7, weights=distance...........................
# [CV 4/5; 13/20] END n_neighbors=7, weights=uniform;, score=(train=0.994, test=0.994) total time=   4.9s
# [CV 3/5; 14/20] START n_neighbors=7, weights=distance...........................
# [CV 1/5; 14/20] END n_neighbors=7, weights=distance;, score=(train=0.995, test=0.993) total time=   3.1s
# [CV 4/5; 14/20] START n_neighbors=7, weights=distance...........................
# [CV 5/5; 13/20] END n_neighbors=7, weights=uniform;, score=(train=0.994, test=0.994) total time=   7.1s
# [CV 5/5; 14/20] START n_neighbors=7, weights=distance...........................
# [CV 2/5; 14/20] END n_neighbors=7, weights=distance;, score=(train=0.995, test=0.994) total time=   6.0s
# [CV 1/5; 15/20] START n_neighbors=8, weights=uniform............................
# [CV 3/5; 14/20] END n_neighbors=7, weights=distance;, score=(train=0.995, test=0.993) total time=   4.8s
# [CV 2/5; 15/20] START n_neighbors=8, weights=uniform............................
# [CV 4/5; 14/20] END n_neighbors=7, weights=distance;, score=(train=0.995, test=0.995) total time=   8.4s
# [CV 3/5; 15/20] START n_neighbors=8, weights=uniform............................
# [CV 5/5; 14/20] END n_neighbors=7, weights=distance;, score=(train=0.994, test=0.994) total time=   5.8s
# [CV 4/5; 15/20] START n_neighbors=8, weights=uniform............................
# [CV 1/5; 15/20] END n_neighbors=8, weights=uniform;, score=(train=0.995, test=0.993) total time=   6.8s
# [CV 5/5; 15/20] START n_neighbors=8, weights=uniform............................
# [CV 2/5; 15/20] END n_neighbors=8, weights=uniform;, score=(train=0.994, test=0.993) total time=   6.3s
# [CV 1/5; 16/20] START n_neighbors=8, weights=distance...........................
# [CV 3/5; 15/20] END n_neighbors=8, weights=uniform;, score=(train=0.994, test=0.994) total time=   6.5s
# [CV 2/5; 16/20] START n_neighbors=8, weights=distance...........................
# [CV 4/5; 15/20] END n_neighbors=8, weights=uniform;, score=(train=0.994, test=0.995) total time=   6.5s
# [CV 3/5; 16/20] START n_neighbors=8, weights=distance...........................
# [CV 1/5; 16/20] END n_neighbors=8, weights=distance;, score=(train=0.995, test=0.993) total time=   6.2s
# [CV 4/5; 16/20] START n_neighbors=8, weights=distance...........................
# [CV 5/5; 15/20] END n_neighbors=8, weights=uniform;, score=(train=0.994, test=0.995) total time=   8.3s
# [CV 5/5; 16/20] START n_neighbors=8, weights=distance...........................
# [CV 2/5; 16/20] END n_neighbors=8, weights=distance;, score=(train=0.995, test=0.994) total time=   5.6s
# [CV 1/5; 17/20] START n_neighbors=9, weights=uniform............................
# [CV 3/5; 16/20] END n_neighbors=8, weights=distance;, score=(train=0.995, test=0.994) total time=   4.2s
# [CV 2/5; 17/20] START n_neighbors=9, weights=uniform............................
# [CV 4/5; 16/20] END n_neighbors=8, weights=distance;, score=(train=0.995, test=0.995) total time=   4.7s
# [CV 3/5; 17/20] START n_neighbors=9, weights=uniform............................
# [CV 5/5; 16/20] END n_neighbors=8, weights=distance;, score=(train=0.995, test=0.995) total time=   4.7s
# [CV 4/5; 17/20] START n_neighbors=9, weights=uniform............................
# [CV 1/5; 17/20] END n_neighbors=9, weights=uniform;, score=(train=0.995, test=0.993) total time=   7.1s
# [CV 5/5; 17/20] START n_neighbors=9, weights=uniform............................
# [CV 2/5; 17/20] END n_neighbors=9, weights=uniform;, score=(train=0.994, test=0.994) total time=   8.9s
# [CV 1/5; 18/20] START n_neighbors=9, weights=distance...........................
# [CV 3/5; 17/20] END n_neighbors=9, weights=uniform;, score=(train=0.994, test=0.994) total time=   9.6s
# [CV 2/5; 18/20] START n_neighbors=9, weights=distance...........................
# [CV 4/5; 17/20] END n_neighbors=9, weights=uniform;, score=(train=0.994, test=0.995) total time=   5.3s
# [CV 3/5; 18/20] START n_neighbors=9, weights=distance...........................
# [CV 1/5; 18/20] END n_neighbors=9, weights=distance;, score=(train=0.995, test=0.993) total time=   5.2s
# [CV 5/5; 17/20] END n_neighbors=9, weights=uniform;, score=(train=0.994, test=0.995) total time=   7.3s
# [CV 4/5; 18/20] START n_neighbors=9, weights=distance...........................
# [CV 5/5; 18/20] START n_neighbors=9, weights=distance...........................
# [CV 2/5; 18/20] END n_neighbors=9, weights=distance;, score=(train=0.995, test=0.994) total time=   5.3s
# [CV 1/5; 19/20] START n_neighbors=10, weights=uniform...........................
# [CV 3/5; 18/20] END n_neighbors=9, weights=distance;, score=(train=0.995, test=0.994) total time=   5.7s
# [CV 2/5; 19/20] START n_neighbors=10, weights=uniform...........................
# [CV 5/5; 18/20] END n_neighbors=9, weights=distance;, score=(train=0.995, test=0.995) total time=   5.8s
# [CV 3/5; 19/20] START n_neighbors=10, weights=uniform...........................
# [CV 4/5; 18/20] END n_neighbors=9, weights=distance;, score=(train=0.995, test=0.995) total time=   6.0s
# [CV 4/5; 19/20] START n_neighbors=10, weights=uniform...........................
# [CV 1/5; 19/20] END n_neighbors=10, weights=uniform;, score=(train=0.995, test=0.993) total time=   6.4s
# [CV 5/5; 19/20] START n_neighbors=10, weights=uniform...........................
# [CV 2/5; 19/20] END n_neighbors=10, weights=uniform;, score=(train=0.994, test=0.994) total time=   6.9s
# [CV 1/5; 20/20] START n_neighbors=10, weights=distance..........................
# [CV 3/5; 19/20] END n_neighbors=10, weights=uniform;, score=(train=0.995, test=0.994) total time=   6.5s
# [CV 2/5; 20/20] START n_neighbors=10, weights=distance..........................
# [CV 4/5; 19/20] END n_neighbors=10, weights=uniform;, score=(train=0.994, test=0.995) total time=   6.4s
# [CV 3/5; 20/20] START n_neighbors=10, weights=distance..........................
# [CV 1/5; 20/20] END n_neighbors=10, weights=distance;, score=(train=0.995, test=0.993) total time=   5.0s
# [CV 4/5; 20/20] START n_neighbors=10, weights=distance..........................
# [CV 5/5; 19/20] END n_neighbors=10, weights=uniform;, score=(train=0.994, test=0.995) total time=   6.5s
# [CV 5/5; 20/20] START n_neighbors=10, weights=distance..........................
# [CV 2/5; 20/20] END n_neighbors=10, weights=distance;, score=(train=0.995, test=0.994) total time=   5.0s
# [CV 3/5; 20/20] END n_neighbors=10, weights=distance;, score=(train=0.995, test=0.994) total time=   5.9s
# [CV 4/5; 20/20] END n_neighbors=10, weights=distance;, score=(train=0.995, test=0.995) total time=   5.2s
# [CV 5/5; 20/20] END n_neighbors=10, weights=distance;, score=(train=0.995, test=0.995) total time=   4.7s
# 0.9942523777059472
# {'n_neighbors': 10, 'weights': 'distance'}
# KNeighborsClassifier(n_neighbors=10, weights='distance')

# %%
# %%time
# K-Nearest Neighbor
knn = KNeighborsClassifier(n_neighbors=10, weights='distance')
y_pred_knn = knn.fit(x_train, y_train).predict(x_test)

# Evaluate
evaluate("K-Nearest Neighbor", y_test, y_pred_knn)
# Out:
# CPU times: user 4.76 s, sys: 104 ms, total: 4.86 s
# Wall time: 5.81 s
#                            K-Nearest Neighbor
# Accuracy Score                       0.994873
# Confusion Matrix  [[53985, 180], [131, 6368]]
# Precision Score                      0.972511
# Recall Score                         0.979843
# F1 Score                             0.976163

# %%
# %%time
# Decision Tree
dt = DecisionTreeClassifier(random_state=0)
y_pred_dt = dt.fit(x_train, y_train).predict(x_test)

# Evaluate
evaluate("Decision Tree", y_test, y_pred_dt)
# Out:
# CPU times: user 391 ms, sys: 13.6 ms, total: 405 ms
# Wall time: 465 ms
#                                 Decision Tree
# Accuracy Score                       0.994939
# Confusion Matrix  [[54028, 137], [170, 6329]]
# Precision Score                      0.978812
# Recall Score                         0.973842
# F1 Score                             0.976321

# %%
# %%time
# Random Forest
rf = RandomForestClassifier(max_depth=2, random_state=0)
y_pred_rf = rf.fit(x_train, y_train).predict(x_test)

# Evaluate
evaluate("Random Forest", y_test, y_pred_rf)
# Out:
# CPU times: user 1.89 s, sys: 47.8 ms, total: 1.94 s
# Wall time: 2.19 s
#                                 Random Forest
# Accuracy Score                       0.991758
# Confusion Matrix  [[54043, 122], [378, 6121]]
# Precision Score                      0.980458
# Recall Score                         0.941837
# F1 Score                              0.96076

# %% [markdown]
# ## Combine Classifiers and Test

# %%
# %%time
# Linear Regression, SVM, Decision Tree, KNearest Neighbor, Random Forest, Naive Baiyes Gaussian
# Bests: KNN + DT

# knn1 = KNeighborsClassifier(n_neighbors=5).fit(x_train, y_train)
knn_dt = VotingClassifier(estimators=[('knn', knn), ('dt', dt)], voting='hard')
y_pred_knn_dt = knn_dt.fit(x_train, y_train).predict(x_test)
evaluate("KNN + DT", y_test, y_pred_knn_dt)
# Out:
# CPU times: user 5.42 s, sys: 113 ms, total: 5.53 s
# Wall time: 6.4 s
#                                      KNN + DT
# Accuracy Score                       0.994939
# Confusion Matrix  [[54029, 136], [171, 6328]]
# Precision Score                       0.97896
# Recall Score                         0.973688
# F1 Score                             0.976317

# %%
# %%time
rf_dt = VotingClassifier(estimators=[('rf', rf), ('dt', dt)], voting='hard')
y_pred_rf_dt = rf_dt.fit(x_train, y_train).predict(x_test)
evaluate("RF + DT", y_test, y_pred_rf_dt)
# Out:
# CPU times: user 2.52 s, sys: 54.4 ms, total: 2.57 s
# Wall time: 3.08 s
#                                      RF + DT
# Accuracy Score                      0.991741
# Confusion Matrix  [[54070, 95], [406, 6093]]
# Precision Score                     0.984648
# Recall Score                        0.937529
# F1 Score                            0.960511

# %%
# %%time
rf_knn = VotingClassifier(estimators=[('rf', rf), ('knn', knn)], voting='hard')
y_pred_rf_knn = rf_knn.fit(x_train, y_train).predict(x_test)
evaluate("RF + KNN", y_test, y_pred_rf_knn)
# Out:
# CPU times: user 6.65 s, sys: 133 ms, total: 6.79 s
# Wall time: 7.88 s
#                                     RF + KNN
# Accuracy Score                      0.991708
# Confusion Matrix  [[54068, 97], [406, 6093]]
# Precision Score                      0.98433
# Recall Score                        0.937529
# F1 Score                            0.960359

# %%
# %%time
rf_svm = VotingClassifier(estimators=[('rf', rf), ('svm', svm)], voting='hard')
y_pred_rf_svm = rf_svm.fit(x_train, y_train).predict(x_test)
evaluate("RF + SVM", y_test, y_pred_rf_svm)
# Out:
# CPU times: user 1min 25s, sys: 1.23 s, total: 1min 26s
# Wall time: 1min 33s
#                                     RF + SVM
# Accuracy Score                      0.985313
# Confusion Matrix  [[54093, 72], [819, 5680]]
# Precision Score                     0.987483
# Recall Score                        0.873981
# F1 Score                            0.927271

# %%
# convert model to pure Javascript code
classifier = dt.fit(x_train, y_train)
model_to_javascript = m2c.export_to_javascript(classifier)
print(model_to_javascript)
# Out:
# function score(input) {
#     var var0;
#     if (input[3] <= 1.5) {
#         if (input[0] <= 35.5) {
#             if (input[0] <= 31.5) {
#                 if (input[3] <= 0.5) {
#                     var0 = [1.0, 0.0];
#                 } else {
#                     if (input[0] <= 28.5) {
#                         if (input[0] <= 18.5) {
#                             if (input[0] <= 12.5) {
#                                 var0 = [1.0, 0.0];
#                             } else {
#                                 if (input[0] <= 17.5) {
#                                     if (input[0] <= 14.5) {
#                                         if (input[0] <= 13.5) {
#                                             var0 = [0.9615384615384616, 0.038461538461538464];
#                                         } else {
#                                             var0 = [1.0, 0.0];
#                                         }
#                                     } else {
#                                         if (input[0] <= 15.5) {
#                                             var0 = [0.9347826086956522, 0.06521739130434782];
#                                         } else {
#                                             if (input[0] <= 16.5) {
#                                                 var0 = [0.9866666666666667, 0.013333333333333334];
#                                             } else {
#                                                 var0 = [0.952, 0.048];
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     var0 = [0.9865591397849462, 0.013440860215053764];
#                                 }
#                             }
#                         } else {
#                             if (input[0] <= 27.5) {
#                                 if (input[0] <= 21.5) {
#                                     if (input[0] <= 19.5) {
#                                         var0 = [0.9966850828729282, 0.0033149171270718232];
#                                     } else {
#                                         if (input[0] <= 20.5) {
#                                             var0 = [0.9928710304601426, 0.007128969539857421];
#                                         } else {
#                                             var0 = [0.9946865037194474, 0.005313496280552604];
#                                         }
#                                     }
#                                 } else {
#                                     if (input[0] <= 22.5) {
#                                         var0 = [0.9983489268024216, 0.001651073197578426];
#                                     } else {
#                                         if (input[0] <= 26.5) {
#                                             if (input[0] <= 25.5) {
#                                                 if (input[0] <= 23.5) {
#                                                     var0 = [0.9962039045553145, 0.003796095444685466];
#                                                 } else {
#                                                     if (input[0] <= 24.5) {
#                                                         var0 = [0.9941427050053249, 0.005857294994675187];
#                                                     } else {
#                                                         var0 = [0.9950284090909091, 0.004971590909090909];
#                                                     }
#                                                 }
#                                             } else {
#                                                 var0 = [0.998876404494382, 0.0011235955056179776];
#                                             }
#                                         } else {
#                                             var0 = [0.9929873772791024, 0.0070126227208976155];
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 var0 = [0.9844097995545658, 0.015590200445434299];
#                             }
#                         }
#                     } else {
#                         if (input[0] <= 30.5) {
#                             if (input[0] <= 29.5) {
#                                 var0 = [0.9669117647058824, 0.03308823529411765];
#                             } else {
#                                 var0 = [0.9725274725274725, 0.027472527472527472];
#                             }
#                         } else {
#                             var0 = [0.95, 0.05];
#                         }
#                     }
#                 }
#             } else {
#                 if (input[3] <= 0.5) {
#                     var0 = [1.0, 0.0];
#                 } else {
#                     if (input[0] <= 34.5) {
#                         if (input[0] <= 33.5) {
#                             if (input[0] <= 32.5) {
#                                 var0 = [0.5254237288135594, 0.4745762711864407];
#                             } else {
#                                 var0 = [0.7419354838709677, 0.25806451612903225];
#                             }
#                         } else {
#                             var0 = [0.4, 0.6];
#                         }
#                     } else {
#                         var0 = [0.7575757575757576, 0.24242424242424243];
#                     }
#                 }
#             }
#         } else {
#             if (input[3] <= 0.5) {
#                 var0 = [1.0, 0.0];
#             } else {
#                 if (input[1] <= 0.5) {
#                     if (input[0] <= 57.5) {
#                         if (input[0] <= 40.5) {
#                             if (input[0] <= 39.5) {
#                                 if (input[0] <= 36.5) {
#                                     var0 = [0.12169312169312169, 0.8783068783068783];
#                                 } else {
#                                     if (input[0] <= 37.5) {
#                                         var0 = [0.6428571428571429, 0.35714285714285715];
#                                     } else {
#                                         if (input[0] <= 38.5) {
#                                             var0 = [0.2682926829268293, 0.7317073170731707];
#                                         } else {
#                                             var0 = [0.15254237288135594, 0.847457627118644];
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 var0 = [0.030303030303030304, 0.9696969696969697];
#                             }
#                         } else {
#                             if (input[0] <= 42.5) {
#                                 if (input[0] <= 41.5) {
#                                     var0 = [0.34782608695652173, 0.6521739130434783];
#                                 } else {
#                                     var0 = [0.2692307692307692, 0.7307692307692307];
#                                 }
#                             } else {
#                                 if (input[0] <= 44.5) {
#                                     if (input[0] <= 43.5) {
#                                         var0 = [0.17307692307692307, 0.8269230769230769];
#                                     } else {
#                                         var0 = [0.0990990990990991, 0.9009009009009009];
#                                     }
#                                 } else {
#                                     if (input[0] <= 48.5) {
#                                         if (input[0] <= 47.5) {
#                                             if (input[0] <= 46.5) {
#                                                 if (input[0] <= 45.5) {
#                                                     var0 = [0.24, 0.76];
#                                                 } else {
#                                                     var0 = [0.3181818181818182, 0.6818181818181818];
#                                                 }
#                                             } else {
#                                                 var0 = [0.22727272727272727, 0.7727272727272727];
#                                             }
#                                         } else {
#                                             var0 = [0.6666666666666666, 0.3333333333333333];
#                                         }
#                                     } else {
#                                         if (input[0] <= 50.5) {
#                                             if (input[0] <= 49.5) {
#                                                 var0 = [0.18181818181818182, 0.8181818181818182];
#                                             } else {
#                                                 var0 = [0.15384615384615385, 0.8461538461538461];
#                                             }
#                                         } else {
#                                             if (input[0] <= 54.5) {
#                                                 if (input[0] <= 52.5) {
#                                                     if (input[0] <= 51.5) {
#                                                         var0 = [0.08333333333333333, 0.9166666666666666];
#                                                     } else {
#                                                         var0 = [0.16666666666666666, 0.8333333333333334];
#                                                     }
#                                                 } else {
#                                                     if (input[0] <= 53.5) {
#                                                         var0 = [0.1, 0.9];
#                                                     } else {
#                                                         var0 = [0.09090909090909091, 0.9090909090909091];
#                                                     }
#                                                 }
#                                             } else {
#                                                 if (input[0] <= 55.5) {
#                                                     var0 = [0.42857142857142855, 0.5714285714285714];
#                                                 } else {
#                                                     if (input[0] <= 56.5) {
#                                                         var0 = [0.09523809523809523, 0.9047619047619048];
#                                                     } else {
#                                                         var0 = [0.12, 0.88];
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     } else {
#                         if (input[0] <= 110.0) {
#                             if (input[0] <= 95.5) {
#                                 if (input[0] <= 81.5) {
#                                     if (input[0] <= 78.5) {
#                                         if (input[0] <= 64.5) {
#                                             if (input[0] <= 60.5) {
#                                                 if (input[0] <= 59.5) {
#                                                     if (input[0] <= 58.5) {
#                                                         var0 = [0.07692307692307693, 0.9230769230769231];
#                                                     } else {
#                                                         var0 = [0.058823529411764705, 0.9411764705882353];
#                                                     }
#                                                 } else {
#                                                     var0 = [0.14285714285714285, 0.8571428571428571];
#                                                 }
#                                             } else {
#                                                 if (input[0] <= 62.5) {
#                                                     if (input[0] <= 61.5) {
#                                                         var0 = [0.0, 1.0];
#                                                     } else {
#                                                         var0 = [0.0625, 0.9375];
#                                                     }
#                                                 } else {
#                                                     var0 = [0.0, 1.0];
#                                                 }
#                                             }
#                                         } else {
#                                             if (input[0] <= 65.5) {
#                                                 var0 = [0.6, 0.4];
#                                             } else {
#                                                 if (input[0] <= 66.5) {
#                                                     var0 = [0.037037037037037035, 0.9629629629629629];
#                                                 } else {
#                                                     if (input[0] <= 68.5) {
#                                                         if (input[0] <= 67.5) {
#                                                             var0 = [0.1, 0.9];
#                                                         } else {
#                                                             var0 = [0.5, 0.5];
#                                                         }
#                                                     } else {
#                                                         if (input[0] <= 72.5) {
#                                                             if (input[0] <= 71.5) {
#                                                                 if (input[0] <= 70.5) {
#                                                                     if (input[0] <= 69.5) {
#                                                                         var0 = [0.05555555555555555, 0.9444444444444444];
#                                                                     } else {
#                                                                         var0 = [0.03333333333333333, 0.9666666666666667];
#                                                                     }
#                                                                 } else {
#                                                                     var0 = [0.1111111111111111, 0.8888888888888888];
#                                                                 }
#                                                             } else {
#                                                                 var0 = [0.0, 1.0];
#                                                             }
#                                                         } else {
#                                                             if (input[0] <= 74.5) {
#                                                                 if (input[0] <= 73.5) {
#                                                                     var0 = [0.125, 0.875];
#                                                                 } else {
#                                                                     var0 = [0.125, 0.875];
#                                                                 }
#                                                             } else {
#                                                                 if (input[0] <= 77.5) {
#                                                                     if (input[0] <= 76.5) {
#                                                                         if (input[0] <= 75.5) {
#                                                                             var0 = [0.0, 1.0];
#                                                                         } else {
#                                                                             var0 = [0.16666666666666666, 0.8333333333333334];
#                                                                         }
#                                                                     } else {
#                                                                         var0 = [0.0, 1.0];
#                                                                     }
#                                                                 } else {
#                                                                     var0 = [0.16666666666666666, 0.8333333333333334];
#                                                                 }
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     } else {
#                                         var0 = [0.0, 1.0];
#                                     }
#                                 } else {
#                                     if (input[0] <= 87.5) {
#                                         if (input[0] <= 86.5) {
#                                             if (input[0] <= 82.5) {
#                                                 var0 = [0.5, 0.5];
#                                             } else {
#                                                 if (input[0] <= 84.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     if (input[0] <= 85.5) {
#                                                         var0 = [0.16666666666666666, 0.8333333333333334];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 }
#                                             }
#                                         } else {
#                                             var0 = [0.75, 0.25];
#                                         }
#                                     } else {
#                                         if (input[0] <= 90.5) {
#                                             if (input[0] <= 88.5) {
#                                                 var0 = [0.1, 0.9];
#                                             } else {
#                                                 var0 = [0.0, 1.0];
#                                             }
#                                         } else {
#                                             if (input[0] <= 94.5) {
#                                                 if (input[0] <= 92.5) {
#                                                     if (input[0] <= 91.5) {
#                                                         var0 = [0.14285714285714285, 0.8571428571428571];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 } else {
#                                                     if (input[0] <= 93.5) {
#                                                         var0 = [0.14285714285714285, 0.8571428571428571];
#                                                     } else {
#                                                         var0 = [0.14285714285714285, 0.8571428571428571];
#                                                     }
#                                                 }
#                                             } else {
#                                                 var0 = [0.25, 0.75];
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (input[0] <= 107.5) {
#                                     if (input[0] <= 104.5) {
#                                         if (input[0] <= 103.5) {
#                                             if (input[0] <= 99.5) {
#                                                 if (input[0] <= 98.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     var0 = [0.2, 0.8];
#                                                 }
#                                             } else {
#                                                 var0 = [0.0, 1.0];
#                                             }
#                                         } else {
#                                             var0 = [0.08333333333333333, 0.9166666666666666];
#                                         }
#                                     } else {
#                                         var0 = [0.0, 1.0];
#                                     }
#                                 } else {
#                                     if (input[0] <= 108.5) {
#                                         var0 = [0.047619047619047616, 0.9523809523809523];
#                                     } else {
#                                         var0 = [0.09090909090909091, 0.9090909090909091];
#                                     }
#                                 }
#                             }
#                         } else {
#                             if (input[0] <= 119.5) {
#                                 if (input[0] <= 113.0) {
#                                     var0 = [1.0, 0.0];
#                                 } else {
#                                     if (input[0] <= 115.5) {
#                                         var0 = [0.0, 1.0];
#                                     } else {
#                                         var0 = [1.0, 0.0];
#                                     }
#                                 }
#                             } else {
#                                 if (input[0] <= 147.0) {
#                                     if (input[0] <= 139.5) {
#                                         if (input[0] <= 131.0) {
#                                             var0 = [0.0, 1.0];
#                                         } else {
#                                             if (input[0] <= 134.0) {
#                                                 var0 = [0.5, 0.5];
#                                             } else {
#                                                 var0 = [0.0, 1.0];
#                                             }
#                                         }
#                                     } else {
#                                         if (input[0] <= 142.5) {
#                                             var0 = [0.5, 0.5];
#                                         } else {
#                                             var0 = [1.0, 0.0];
#                                         }
#                                     }
#                                 } else {
#                                     var0 = [0.0, 1.0];
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     if (input[0] <= 172.0) {
#                         if (input[0] <= 125.5) {
#                             var0 = [1.0, 0.0];
#                         } else {
#                             if (input[0] <= 132.0) {
#                                 var0 = [0.0, 1.0];
#                             } else {
#                                 var0 = [1.0, 0.0];
#                             }
#                         }
#                     } else {
#                         var0 = [0.0, 1.0];
#                     }
#                 }
#             }
#         }
#     } else {
#         if (input[0] <= 40.5) {
#             if (input[0] <= 27.5) {
#                 if (input[0] <= 23.5) {
#                     var0 = [1.0, 0.0];
#                 } else {
#                     if (input[0] <= 26.5) {
#                         if (input[0] <= 25.5) {
#                             if (input[0] <= 24.5) {
#                                 var0 = [0.9705882352941176, 0.029411764705882353];
#                             } else {
#                                 var0 = [0.9782608695652174, 0.021739130434782608];
#                             }
#                         } else {
#                             var0 = [1.0, 0.0];
#                         }
#                     } else {
#                         var0 = [0.9565217391304348, 0.043478260869565216];
#                     }
#                 }
#             } else {
#                 if (input[3] <= 2.5) {
#                     if (input[0] <= 35.5) {
#                         if (input[0] <= 29.5) {
#                             if (input[0] <= 28.5) {
#                                 var0 = [0.7368421052631579, 0.2631578947368421];
#                             } else {
#                                 var0 = [0.7647058823529411, 0.23529411764705882];
#                             }
#                         } else {
#                             if (input[0] <= 30.5) {
#                                 var0 = [1.0, 0.0];
#                             } else {
#                                 if (input[0] <= 34.5) {
#                                     if (input[0] <= 31.5) {
#                                         var0 = [0.7777777777777778, 0.2222222222222222];
#                                     } else {
#                                         if (input[0] <= 33.5) {
#                                             if (input[0] <= 32.5) {
#                                                 var0 = [0.6666666666666666, 0.3333333333333333];
#                                             } else {
#                                                 var0 = [0.6666666666666666, 0.3333333333333333];
#                                             }
#                                         } else {
#                                             var0 = [0.75, 0.25];
#                                         }
#                                     }
#                                 } else {
#                                     var0 = [1.0, 0.0];
#                                 }
#                             }
#                         }
#                     } else {
#                         if (input[0] <= 38.5) {
#                             if (input[0] <= 36.5) {
#                                 var0 = [0.7, 0.3];
#                             } else {
#                                 if (input[0] <= 37.5) {
#                                     var0 = [0.5, 0.5];
#                                 } else {
#                                     var0 = [0.4, 0.6];
#                                 }
#                             }
#                         } else {
#                             if (input[0] <= 39.5) {
#                                 var0 = [1.0, 0.0];
#                             } else {
#                                 var0 = [0.75, 0.25];
#                             }
#                         }
#                     }
#                 } else {
#                     if (input[0] <= 39.5) {
#                         if (input[3] <= 3.5) {
#                             if (input[0] <= 35.5) {
#                                 if (input[0] <= 33.5) {
#                                     if (input[0] <= 32.0) {
#                                         var0 = [0.5, 0.5];
#                                     } else {
#                                         var0 = [0.6666666666666666, 0.3333333333333333];
#                                     }
#                                 } else {
#                                     if (input[0] <= 34.5) {
#                                         var0 = [0.0, 1.0];
#                                     } else {
#                                         var0 = [0.3333333333333333, 0.6666666666666666];
#                                     }
#                                 }
#                             } else {
#                                 if (input[0] <= 37.5) {
#                                     if (input[0] <= 36.5) {
#                                         var0 = [1.0, 0.0];
#                                     } else {
#                                         var0 = [0.6666666666666666, 0.3333333333333333];
#                                     }
#                                 } else {
#                                     if (input[0] <= 38.5) {
#                                         var0 = [0.3333333333333333, 0.6666666666666666];
#                                     } else {
#                                         var0 = [0.5, 0.5];
#                                     }
#                                 }
#                             }
#                         } else {
#                             var0 = [1.0, 0.0];
#                         }
#                     } else {
#                         if (input[3] <= 4.5) {
#                             var0 = [1.0, 0.0];
#                         } else {
#                             var0 = [0.0, 1.0];
#                         }
#                     }
#                 }
#             }
#         } else {
#             if (input[0] <= 47.5) {
#                 if (input[0] <= 42.5) {
#                     if (input[0] <= 41.5) {
#                         var0 = [0.0, 1.0];
#                     } else {
#                         if (input[3] <= 2.5) {
#                             var0 = [0.25, 0.75];
#                         } else {
#                             if (input[3] <= 4.0) {
#                                 var0 = [0.75, 0.25];
#                             } else {
#                                 var0 = [0.0, 1.0];
#                             }
#                         }
#                     }
#                 } else {
#                     if (input[3] <= 5.0) {
#                         if (input[3] <= 2.5) {
#                             if (input[0] <= 46.5) {
#                                 if (input[0] <= 44.5) {
#                                     if (input[0] <= 43.5) {
#                                         var0 = [0.07142857142857142, 0.9285714285714286];
#                                     } else {
#                                         var0 = [0.06382978723404255, 0.9361702127659575];
#                                     }
#                                 } else {
#                                     if (input[0] <= 45.5) {
#                                         var0 = [0.25, 0.75];
#                                     } else {
#                                         var0 = [0.2, 0.8];
#                                     }
#                                 }
#                             } else {
#                                 var0 = [0.025, 0.975];
#                             }
#                         } else {
#                             if (input[0] <= 44.5) {
#                                 var0 = [0.0, 1.0];
#                             } else {
#                                 if (input[0] <= 46.5) {
#                                     if (input[3] <= 3.5) {
#                                         if (input[0] <= 45.5) {
#                                             var0 = [1.0, 0.0];
#                                         } else {
#                                             var0 = [0.6666666666666666, 0.3333333333333333];
#                                         }
#                                     } else {
#                                         var0 = [1.0, 0.0];
#                                     }
#                                 } else {
#                                     var0 = [0.3333333333333333, 0.6666666666666666];
#                                 }
#                             }
#                         }
#                     } else {
#                         var0 = [0.0, 1.0];
#                     }
#                 }
#             } else {
#                 if (input[1] <= 0.5) {
#                     if (input[3] <= 5.5) {
#                         if (input[0] <= 65.5) {
#                             if (input[3] <= 3.5) {
#                                 if (input[0] <= 59.5) {
#                                     if (input[3] <= 2.5) {
#                                         if (input[0] <= 50.5) {
#                                             var0 = [0.0, 1.0];
#                                         } else {
#                                             if (input[0] <= 55.5) {
#                                                 if (input[0] <= 52.5) {
#                                                     if (input[0] <= 51.5) {
#                                                         var0 = [0.16666666666666666, 0.8333333333333334];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 } else {
#                                                     if (input[0] <= 53.5) {
#                                                         var0 = [0.3333333333333333, 0.6666666666666666];
#                                                     } else {
#                                                         if (input[0] <= 54.5) {
#                                                             var0 = [0.1111111111111111, 0.8888888888888888];
#                                                         } else {
#                                                             var0 = [0.14285714285714285, 0.8571428571428571];
#                                                         }
#                                                     }
#                                                 }
#                                             } else {
#                                                 var0 = [0.0, 1.0];
#                                             }
#                                         }
#                                     } else {
#                                         var0 = [0.0, 1.0];
#                                     }
#                                 } else {
#                                     if (input[0] <= 60.5) {
#                                         if (input[3] <= 2.5) {
#                                             var0 = [0.25, 0.75];
#                                         } else {
#                                             var0 = [0.2857142857142857, 0.7142857142857143];
#                                         }
#                                     } else {
#                                         if (input[0] <= 61.5) {
#                                             var0 = [0.0, 1.0];
#                                         } else {
#                                             if (input[0] <= 62.5) {
#                                                 if (input[3] <= 2.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     var0 = [0.5, 0.5];
#                                                 }
#                                             } else {
#                                                 if (input[3] <= 2.5) {
#                                                     if (input[0] <= 64.5) {
#                                                         var0 = [0.0, 1.0];
#                                                     } else {
#                                                         var0 = [0.2, 0.8];
#                                                     }
#                                                 } else {
#                                                     var0 = [0.0, 1.0];
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (input[0] <= 56.0) {
#                                     if (input[0] <= 53.5) {
#                                         if (input[3] <= 4.5) {
#                                             var0 = [1.0, 0.0];
#                                         } else {
#                                             var0 = [0.0, 1.0];
#                                         }
#                                     } else {
#                                         var0 = [1.0, 0.0];
#                                     }
#                                 } else {
#                                     var0 = [0.0, 1.0];
#                                 }
#                             }
#                         } else {
#                             if (input[0] <= 120.5) {
#                                 if (input[0] <= 119.5) {
#                                     if (input[0] <= 69.5) {
#                                         var0 = [0.0, 1.0];
#                                     } else {
#                                         if (input[0] <= 75.5) {
#                                             if (input[0] <= 74.5) {
#                                                 if (input[3] <= 2.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     if (input[0] <= 70.5) {
#                                                         if (input[3] <= 3.5) {
#                                                             var0 = [0.07142857142857142, 0.9285714285714286];
#                                                         } else {
#                                                             var0 = [0.0, 1.0];
#                                                         }
#                                                     } else {
#                                                         if (input[0] <= 72.5) {
#                                                             var0 = [0.0, 1.0];
#                                                         } else {
#                                                             if (input[0] <= 73.5) {
#                                                                 if (input[3] <= 3.5) {
#                                                                     var0 = [0.2, 0.8];
#                                                                 } else {
#                                                                     var0 = [0.0, 1.0];
#                                                                 }
#                                                             } else {
#                                                                 var0 = [0.0, 1.0];
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             } else {
#                                                 if (input[3] <= 2.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     if (input[3] <= 3.5) {
#                                                         var0 = [0.3333333333333333, 0.6666666666666666];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 }
#                                             }
#                                         } else {
#                                             if (input[3] <= 2.5) {
#                                                 if (input[0] <= 115.5) {
#                                                     if (input[0] <= 100.5) {
#                                                         if (input[0] <= 99.5) {
#                                                             if (input[0] <= 86.5) {
#                                                                 var0 = [0.0, 1.0];
#                                                             } else {
#                                                                 if (input[0] <= 87.5) {
#                                                                     var0 = [1.0, 0.0];
#                                                                 } else {
#                                                                     var0 = [0.0, 1.0];
#                                                                 }
#                                                             }
#                                                         } else {
#                                                             var0 = [0.2, 0.8];
#                                                         }
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 } else {
#                                                     if (input[0] <= 116.5) {
#                                                         var0 = [0.5, 0.5];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 }
#                                             } else {
#                                                 if (input[0] <= 88.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     if (input[0] <= 89.5) {
#                                                         if (input[3] <= 3.5) {
#                                                             var0 = [0.5, 0.5];
#                                                         } else {
#                                                             var0 = [0.0, 1.0];
#                                                         }
#                                                     } else {
#                                                         if (input[3] <= 3.5) {
#                                                             var0 = [0.0, 1.0];
#                                                         } else {
#                                                             if (input[0] <= 104.5) {
#                                                                 var0 = [0.0, 1.0];
#                                                             } else {
#                                                                 if (input[0] <= 105.5) {
#                                                                     var0 = [1.0, 0.0];
#                                                                 } else {
#                                                                     var0 = [0.0, 1.0];
#                                                                 }
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 } else {
#                                     if (input[3] <= 3.5) {
#                                         if (input[3] <= 2.5) {
#                                             var0 = [0.0, 1.0];
#                                         } else {
#                                             var0 = [0.06666666666666667, 0.9333333333333333];
#                                         }
#                                     } else {
#                                         var0 = [0.0, 1.0];
#                                     }
#                                 }
#                             } else {
#                                 var0 = [0.0, 1.0];
#                             }
#                         }
#                     } else {
#                         var0 = [0.0, 1.0];
#                     }
#                 } else {
#                     if (input[3] <= 4.5) {
#                         if (input[0] <= 67.0) {
#                             if (input[3] <= 2.5) {
#                                 var0 = [0.0, 1.0];
#                             } else {
#                                 var0 = [1.0, 0.0];
#                             }
#                         } else {
#                             if (input[0] <= 100.0) {
#                                 if (input[3] <= 2.5) {
#                                     var0 = [0.0, 1.0];
#                                 } else {
#                                     if (input[0] <= 81.0) {
#                                         var0 = [0.0, 1.0];
#                                     } else {
#                                         if (input[0] <= 87.0) {
#                                             var0 = [1.0, 0.0];
#                                         } else {
#                                             var0 = [0.0, 1.0];
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (input[0] <= 114.5) {
#                                     if (input[3] <= 3.5) {
#                                         if (input[0] <= 113.5) {
#                                             if (input[0] <= 104.0) {
#                                                 if (input[3] <= 2.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     var0 = [1.0, 0.0];
#                                                 }
#                                             } else {
#                                                 if (input[0] <= 111.5) {
#                                                     var0 = [0.0, 1.0];
#                                                 } else {
#                                                     if (input[3] <= 2.5) {
#                                                         var0 = [1.0, 0.0];
#                                                     } else {
#                                                         var0 = [0.0, 1.0];
#                                                     }
#                                                 }
#                                             }
#                                         } else {
#                                             var0 = [1.0, 0.0];
#                                         }
#                                     } else {
#                                         var0 = [1.0, 0.0];
#                                     }
#                                 } else {
#                                     if (input[3] <= 2.5) {
#                                         if (input[0] <= 125.5) {
#                                             var0 = [0.0, 1.0];
#                                         } else {
#                                             if (input[0] <= 144.5) {
#                                                 var0 = [1.0, 0.0];
#                                             } else {
#                                                 var0 = [0.0, 1.0];
#                                             }
#                                         }
#                                     } else {
#                                         var0 = [0.0, 1.0];
#                                     }
#                                 }
#                             }
#                         }
#                     } else {
#                         var0 = [0.0, 1.0];
#                     }
#                 }
#             }
#         }
#     }
#     return var0;
# }
